# %%
import numpy as np
import pandas as pd

df = pd.read_csv("data/leagues_MLB_2016-standard-pitching_players_standard_pitching.csv")
# Out:
# Traceback (most recent call last):
#   File "/Users/jordandarefsky/anaconda/envs/py3k/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2885, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-02afacc3b4ab>", line 4, in <module>
#     df = pd.read_csv("data/leagues_MLB_2016-standard-pitching_players_standard_pitching.csv")
#   File "/Users/jordandarefsky/anaconda/envs/py3k/lib/python3.5/site-packages/pandas/io/parsers.py", line 562, in parser_f
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/jordandarefsky/anaconda/envs/py3k/lib/python3.5/site-packages/pandas/io/parsers.py", line 315, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/Users/jordandarefsky/anaconda/envs/py3k/lib/python3.5/site-packages/pandas/io/parsers.py", line 645, in __init__
#     self._make_engine(self.engine)
# ...

# %%
df.head()
# Out:
#   Rk            Name Age   Tm  Lg  W  L  W-L%   ERA   G  ...  WP   BF ERA+  \
# 0  1  Fernando Abad*  30  MIN  AL  1  1  .500  2.16  30  ...   0   96  204
# 1  2     A.J. Achter  27  LAA  AL  0  0   NaN  3.98  12  ...   0   86  103
# 2  3    Austin Adams  29  CLE  AL  0  0   NaN  2.35   7  ...   0   32  204
# 3  4     Tim Adleman  28  CIN  NL  1  1  .500  3.72   4  ...   0   83  115
# 4  5     Matt Albers  33  CHW  AL  2  4  .333  5.23  35  ...   3  138   78
#
#     FIP   WHIP    H9  HR9  BB9   SO9  SO/W
# 0  2.80  1.080   6.8  0.4  2.9   8.3  2.88
# 1  6.21  1.426  11.1  2.2  1.8   4.0  2.25
# 2  4.60  1.174   7.0  2.3  3.5  14.1  4.00
# 3  5.07  1.397   8.4  1.4  4.2   7.4  1.78
# 4  5.64  1.452   9.9  1.7  3.2   5.8  1.82
#
# [5 rows x 35 columns]
